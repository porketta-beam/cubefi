# %%
import dotenv
import os
from langchain_openai import ChatOpenAI

dotenv.load_dotenv(override=True)

api = os.getenv("API2")
default_model = os.getenv("OPENAI_DEFAULT_MODEL")
llm = ChatOpenAI(model="gpt-4.1", api_key=api) #GPT-4o 모델 선택

print(llm.invoke("안녕?").content)
# Out:
# 안녕하세요! 무엇을 도와드릴까요? 😊

# %% [markdown]
# # 여러가지 출력 방식
#
# ## invoke 방식
#
# * 한 번에 출력 결과를 내려주는 방식

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

messages = [("system", "sns에서 음식점을 홍보하는 사람입니다."),
            ("human", "성수동 맛집을 추천해주세요")]

print(llm.invoke(messages).content) # 거짓말이 많으므로 검증하는 과정이 필요함
# Out:
# 네, 성수동은 트렌디한 카페와 다양한 맛집으로 유명한 곳입니다! SNS에서 매력적으로 홍보할 수 있는 성수동 맛집 몇 곳을 추천드릴게요.
#
# ---
#
# ### 1. **자주 등장하는 성수동 맛집 Best 5**
#
# 1. **성수족발**
#    - 대표메뉴: 족발, 보쌈
#    - 특징: 쫄깃한 식감과 깊은 맛, 현지인이 자주 찾는 오래된 맛집
#
# 2. **로우플로우 LOW FLO (카페 & 브런치)**
#    - 대표메뉴: 브런치 플레이트, 오렌지 커피
#    - 특징: 감각적인 인테리어와 시그니처 메뉴, 인스타 핫플
#
# 3. **도우룸 (피자)**
#    - 대표메뉴: 수제 트러플 피자, 루꼴라 피자
#    - 특징: 바삭하고 쫄깃한 도우, 고급스러운 분위기
#
# 4. **성수연방 (푸드코트형 복합 맛집)**
#    - 대표메뉴: 각종 한식, 파스타, 디저트
#    - 특징: 다양한 맛집이 한 공간에! 여러 메뉴를 한 번에 즐길 수 있음
#
# 5. **아마노 (이탈리안 레스토랑)**
#    - 대표메뉴: 홈메이드 파스타, 라자냐
#    - 특징: 합리적인 가격, 편안한 분위기, 데이트와 모임에 강추
#
# ---
#
# ### 2. **SNS 감성으로 추천글 예시**
#
# > 요즘 핫플 성수동 맛집 어디가면 좋을지 고민되죠?
# >
# > 🍕 도우룸에서 바삭한 트러플 피자 한 입,
# > ☕ 로우플로우에서 감성 브런치와 오렌지 커피,
# > 🐽 저녁엔 현지인이 추천하는 성수족발까지!
# >
# > 성수동에서 하루 종~일 맛집투어 어떠세요?
# >
# > #성수동맛집 #핫플 #성수동카페 #서울맛집
#
# ---
#
# 원하시는 분위기(고급, 캐주얼, 디저트)에 따라 추가 추천도 가능합니다. 어떤 음식이나 콘셉트를 더 원하시나요?

# %% [markdown]
# ## stream 방식

# %%
response = llm.stream(messages)

for chunk in response:
    print(chunk.content, end="", flush=True)
# Out:
# 네, 성수동은 요즘 서울에서 가장 핫한 맛집들이 몰려 있는 동네 중 하나죠! 다양한 음식 스타일과 분위기의 레스토랑, 카페, 이자카야 등이 많아 소개하기 좋아요. SNS에서 반응이 좋은 성수동 맛집 몇 군데를 추천해드릴게요.
#
# ### 감각적인 분위기와 맛, 둘 다 잡은 곳
# 1. **성수연방 - 피자뮤직**
#    - 화덕 피자와 이탈리안 요리를 트렌디한 공간에서 즐길 수 있는 곳.
#    - 인스타그래머블한 인테리어와 자연광이 좋아 사진 찍기도 좋아요.
#
# 2. **플로이 (PLOY)**
#    - 미쉐린 빕 구르망 선정된 태국 음식점.
#    - 똠얌꿍, 팟타이 등 대중적인 태국 메뉴와 세련된 플레이팅이 특징.
#
# 3. **자연도소금구이**
#    - 성수동 고기집의 최강자! 두툼한 삼겹살과 자연 소금으로 조리.
#    - 숯불에 구워 고소하고 풍미 있는 맛.
#
# ### 분위기 좋은 브런치 & 카페
# 4. **카페 어니언 성수점**
#    - 성수동 대표 베이커리 카페. 벽돌 공장 느낌의 인테리어.
#    - 페스츄리, 감자빵 등 독특한 베이커리와 커피가 인기.
#
# 5. **로우 파이브 (RAW FIVE)**
#    - 오트밀 맛집으로 유명한 브런치 카페.
#    - 건강하면서도 맛있는 메뉴와 감성적인 인테리어.
#
# ### 색다른 경험, 디저트/이색 음식
# 6. **호랑이식당**
#    - 한국식 중화요리(짜장면, 탕수육 등)와 소울푸드를 감각적으로 재해석.
#    - 감성적인 인테리어와 아기자기한 소품들로 사진 찍기 좋아요.
#
# 7. **엉클비닐**
#    - 특색있는 일본식 이자카야.
#    - 다양한 사케와 이색적인 안주들로 저녁에 찾기 좋아요.
#
# ---
#
# #### SNS 홍보 TIP:
# 가게의 인테리어나 메뉴 비주얼이 뛰어난 곳을 골라, 자연광이 들어오는 시간대의 사진이나 동영상을 촬영하면 반응이 좋아요. 해시태그는 #성수동맛집 #성수맛집 #성수동카페 #서울맛집 등과 해당 음식 종류 해시태그(#피자맛집 #브런치카페 등)도 함께 사용하시면 좋아요!
#
# 궁금한 음식 종류나 분위기가 있으시면 더 맞춤형 추천도 가능합니다!

# %% [markdown]
# ## batch 방식

# %%
messages = [[("system", "당신은 탁구 전문가입니다."),
            ("human", "한국에서 가장 기대되는 남자 탁구 선수는 누구입니까? 그리고 그 선수의 성별은 어떻게 되나요?")],
            [("system", "sns에서 음식점을 홍보하는 사람입니다."),
            ("human", "성수동 맛집을 추천해주세요")],
            [("system", "sns에서 음식점을 홍보하는 사람입니다."),
            ("human", "서울 맛집을 추천해주세요")],
            [("system", "sns에서 음식점을 홍보하는 사람입니다."),
            ("human", "광주 맛집을 추천해주세요")],
            [("system", "sns에서 음식점을 홍보하는 사람입니다."),
            ("human", "울산 맛집을 추천해주세요")],
            ]

response = llm.batch(messages)

for chunk in response:
    print(chunk.content, end="\n ------------------------------------------------------------------------------------------------------------------- \n", flush=True)
# Out:
# 현재(2024년 기준) 한국에서 가장 기대되는 남자 탁구 선수로는 신유빈 선수와 조승민 선수가 자주 언급됩니다. 하지만 질문에서 ‘남자 탁구 선수’를 찾으신 만큼 이들 중 남자 선수를 소개드리겠습니다.
#
# 가장 주목받는 남자 탁구 선수는 ‘조승민’ 선수입니다.
# - 조승민(Cho Seung Min):
#   - **성별:** 남자
#   - **생년월일:** 1997년생
#   - **주요 이력:** 2022 항저우 아시안게임 남자 단체전 금메달, 2024 파리올림픽 국가대표.
#   - **특징:** 빠른 풋워크와 강한 드라이브, 승부 근성.
#   - **향후 전망:** 대형 국제대회에서 대한민국 남자탁구의 에이스로 성장할 것으로 기대받습니다.
#
# 참고로, 신유빈 선수는 여자입니다.
# - 신유빈(Shin Yubin):
#   - **성별:** 여자
#   - **활약상:** 여자 탁구의 간판스타
#
# 정리하자면,
# **한국 남자 탁구에서 가장 기대되는 선수는 ‘조승민’ 선수이고, 그의 성별은 남자입니다.**
#  -------------------------------------------------------------------------------------------------------------------
# 네, 성수동은 요즘 트렌디한 맛집이 많은 동네로 유명하죠! SNS에서 홍보하실 때 활용할 수 있는 핫플레이스와 다양한 스타일의 성수동 맛집을 추천드릴게요.
#
# ---
#
# ### 1. **오늘살롱**
# - **소개**: 분위기 좋은 감성 한식 다이닝펍
# - **대표 메뉴**: 달걀덮밥, 감바스, 한우차돌박이
# - **포인트**: 감각적인 인테리어와 특색 있는 플레이팅으로 사진 찍기 좋아요.
#
# ---
#
# ### 2. **슬로우파크**
# - **소개**: 수제버거 전문점
# - **대표 메뉴**: 슬로우파크버거, 트러플버거, 프렌치프라이
# - **포인트**: 두툼한 패티와 부드러운 번, 감각적인 브런치 카페 분위기!
#
# ---
#
# ### 3. **세컨드키친**
# - **소개**: 샤퀴테리와 와인 페어링이 유명한 퓨전 레스토랑
# - **대표 메뉴**: 훈제안심 샐러드, 라구파스타, 콜드 스프
# - **포인트**: 모던 감성의 인테리어와 세련된 플레이팅으로 SNS 사진 소장각!
#
# ---
#
# ### 4. **자주식당**
# - **소개**: 소박한 분위기에서 즐기는 백반집
# - **대표 메뉴**: 제육볶음, 김치찌개, 된장찌개
# - **포인트**: 현지인 추천 맛집, 가성비도 좋아요.
#
# ---
#
# ### 5. **바게트K**
# - **소개**: 프랑스풍 바게트 샌드위치, 베이커리 카페
# - **대표 메뉴**: 치아바타 샌드위치, 크루아상, 아메리카노
# - **포인트**: 성수동 감성 듬뿍, 브런치 및 디저트에 강추!
#
# ---
#
# #### 홍보 TIP
# - 해시태그: #성수동맛집 #성수핫플 #성수동카페 #성수맛집추천 #오늘뭐먹지
# - 사진은 채광이 좋은 낮 시간대에 촬영하면 더욱 예뻐요!
# - 매장 위치, 예약 가능 여부, 대표 메뉴 영상 등을 함께 올리면 좋습니다.
#
# 혹시 특정한 음식 종류나 분위기(데이트/가족/혼밥 등)가 필요하다면 추가로 추천해드릴 수 있습니다!
#  -------------------------------------------------------------------------------------------------------------------
# 물론이죠! SNS에서 홍보하기 좋은 서울의 인기 맛집을 추천해 드릴게요. 사진/영상 비주얼, 스토리성, 트렌드성 모두 고려해서 선별했습니다.
#
# ---
#
# ### 1. **을지로 노포 감성**
# - **을지로 골뱅이**
#   - 을지로 노포의 정취를 느낄 수 있는 곳. 골뱅이 무침, 소주 한잔, 레트로 인테리어가 인생샷 각!
# - **을지로3가 풍년식당**
#   - 돼지불백의 레전드. 연탄불 향, 투박한 사기그릇. 분위기와 음식 모두 완벽합니다.
#
# ### 2. **감각적인 카페 겸 브런치 맛집**
# - **성수 브루클린 더 버거 조인트**
#   - 압도적인 버거 비주얼과 성수만의 힙한 분위기. 브런치 사진, 감성샷 모두 찍기 좋아요.
# - **한남동 마마돈크라이**
#   - 빈티지한 인테리어, 고급스러운 디저트와 커피, SNS 감성에 제격.
#
# ### 3. **핫한 신상 트렌드 맛집**
# - **청담동 모수**
#   - 미쉐린 2스타 한식 파인다이닝, 세련된 플레이팅과 인테리어로 '명품' 사진 가능!
# - **연남동 몽탄**
#   - 흑돼지 목살구이의 신흥 강자. 대기줄 길지만, 비주얼과 맛 모두 인증 각입니다.
#
# ### 4. **퓨전 한식 & 든든한 식사**
# - **망원동 소쿠리**
#   - 한식 반상과 퓨전 요리의 만남. 보기 좋은 접시에 데코까지 완벽하게 담겨 나옴.
# - **홍대 돈카츠 위카츠**
#   - 두툼한 수제 돈카츠와 아기자기한 인테리어. 일본 느낌 가득한 사진과 리스팅에 추천!
#
# ### 5. **비건 & 건강식 트렌드**
# - **이태원 플랜트**
#   - 비건 디저트와 샐러드, 건강식도 이렇게 맛있고 예쁘다! 채식주의 타깃 노릴 때 강추.
# - **한남동 썬더버거**
#   - 국내산 두부로 만든 버거. 유니크하고 건강한 메뉴, 젊은 SNS층 사이에서 인기!
#
# ---
#
# **팁:**
# - 계절 메뉴 & 인테리어 포인트 잡아서 사진/영상 컨텐츠 제작 추천
# - 인플루언서 콜라보/체험단 해시태그 활용 #서울맛집 #핫플 #먹방 #카페투어
#
# 궁금한 지역이나, 한식/양식 등 테마가 따로 있으시면 말씀해 주세요! 맞춤으로 좀 더 상세히 제안해드릴 수 있습니다. :)
#  -------------------------------------------------------------------------------------------------------------------
# 물론이죠! 광주는 맛집이 정말 많은 도시로 유명하죠. SNS에서 홍보하기 좋은 비주얼과 독특함을 갖춘 인기 맛집 몇 곳을 추천해드릴게요. 해시태그, 위치 태깅 등도 잘 활용해보시면 좋을 것 같아요!
#
# ---
#
# **광주 SNS 인기 맛집 추천**
#
# 1. **광주 붓처리**
#    - *설명*: 감성적인 인테리어와 독특한 메뉴로 SNS에서 핫한 레스토랑입니다. 수플레 팬케이크와 에그샌드위치가 유명해요!
#    - *위치*: 동구 충장로
#
# 2. **송정떡갈비골목 (박광일떡갈비, 우미관 등)**
#    - *설명*: 송정역 근처에 위치해 광주의 명물 떡갈비를 다양하게 즐길 수 있습니다. 비주얼도 좋아 사진 찍기 좋아요.
#    - *위치*: 광산구 송정동
#
# 3. **시청앞 국밥거리 (수정식당, 장터국밥 등)**
#    - *설명*: 진한 국밥과 푸짐한 반찬. 따끈한 국밥 한 그릇에 정이 느껴지는 곳입니다. 국밥 인증샷은 언제나 대세!
#    - *위치*: 서구 치평동
#
# 4. **청년다방 광주충장로점**
#    - *설명*: 퓨전 떡볶이와 치즈 폭포가 장관인 SNS 대표 떡볶이집.
#    - *위치*: 동구 충장로
#
# 5. **남광주시장 김치찌개 골목**
#    - *설명*: 시장 속 정겨운 분위기와 맛있는 김치찌개. 전통시장 먹방 shot에 제격!
#    - *위치*: 남구 월남동
#
# 6. **카페 작**
#    - *설명*: 감성적인 소품과 비주얼 좋은 커피/디저트로 유명한 인생샷 카페.
#    - *위치*: 동구 예술길
#
# 7. **무등산 보리밥집 (예술길 보리밥, 5.18보리밥 등)**
#    - *설명*: 광주 지역 특색 음식인 보리밥을 현대적으로 풀어낸 곳. 건강한 상차림으로 홍보하기 좋아요.
#    - *위치*: 동구 예술길 일대
#
# ---
#
# **SNS 홍보 TIP**
# - #광주맛집 #광주핫플 #광주먹방 #광주여행 등 해시태그 넣기
# - 매장의 비주얼, 시그니처 메뉴, 특이한 인테리어 등 디테일하게 포스팅
# - 지도, 위치 태깅, 스토리 활용해서 지속적으로 노출하기
#
# 혹시 특정한 음식(한식/양식/카페/일식 등)이나 장소(동구/서구/남구/북구/광산구)로 추천 받고 싶으시면 추가로 말씀해 주세요!
#  -------------------------------------------------------------------------------------------------------------------
# 네, 울산의 맛집을 찾으시나요? 울산에는 다양한 지역별, 음식별로 많은 인기 맛집들이 있습니다. 아래에 몇 군데 추천드릴게요!
#
# ---
#
# ### **울산 대표 맛집 추천 리스트**
#
# #### **1. 장생포 고래고기거리**
# - **특징**: 울산만의 명물, 고래고기! 다양한 고래고기 전문점이 모여있어 특별한 경험 가능.
# - **추천 매장**: 이상복고래고기집, 옛고래고기집
#
# #### **2. 태화강 카페거리**
# - 카페와 먹거리가 어우러진 곳으로 디저트 맛집도 많아요.
# - **추천 카페**: 팩토리카페, 카페거리온
#
# #### **3. 언양불고기**
# - **언양읍**에 위치해 있으며 전통적인 언양식 석쇠불고기 전문점이 유명.
# - **추천 매장**: 언양한우불고기, 온양한우불고기
#
# #### **4. 진미식당 (삼산동)**
# - **메뉴**: 불고기정식, 생선구이
# - **특징**: JTBC ‘수요미식회’에도 소개된 전통 있는 한식당
#
# #### **5. 통도사역 근처 생선구이 골목**
# - 신선한 생선구이와 정갈한 한식 백반 집들이 많아요.
#
# #### **6. 울산 번개반점**
# - **메뉴**: 울산 3대 짬뽕으로 소문난 곳, 얼큰한 짬뽕 국물 추천!
#
# #### **7. 밀면 맛집**
# - 울산의 여름 별미, 밀면!
# - **추천**: 태화동 '부산밀면', ‘중앙밀면’
#
# #### **8. 국밥집**
# - **추천**: 병영식당 (돼지국밥), 장춘옥(소고기국밥)
#
# ---
#
# ### **인스타그램에 올릴 홍보 문구 예시**
# “울산 맛집 탐방 🚗✨ 울산만의 특별한 먹거리, 정성 가득한 한상차림! 이번엔 어디로 가볼까요? 여러분의 울산 맛집 추천도 댓글로 남겨주세요!👇 #울산맛집 #울산여행 #울산고래고기 #울산밀면 #먹스타그램”
#
# ---
#
# 원하시는 음식 종류(한식, 해산물, 디저트, 카페 등)나, 지역(남구, 중구, 동구, 북구)별로도 추가 추천 가능합니다. 더 궁금하신 점 있으시면 알려주세요!
#  -------------------------------------------------------------------------------------------------------------------

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

chat = ChatOpenAI(model_name=default_model, api_key=api, temperature=0.9)

sys = SystemMessage(content="당신은 음악 추천을 해주는 전문 AI입니다.")
msg = HumanMessage(content='재즈바에서 신청하면 인기쟁이 되는 재즈 10곡만 추천해줘.')

aimsg = chat([sys, msg])  # 모델에게 메시지 리스트를 전달하여 응답 받음
print(aimsg.content)
# Out:
# 물론이죠! 재즈바에서 신청하면 분위기도 살리고, 모두가 좋아할 만한 인기 재즈 곡 10곡을 추천해드릴게요.
#
# 1. **Frank Sinatra – Fly Me to the Moon**
#    재즈바에서 가장 사랑받는 곡 중 하나죠. 분위기와 로맨스를 한 번에!
#
# 2. **Chet Baker – My Funny Valentine**
#    감미로운 트럼펫과 보컬이 재즈 감성을 극대화합니다.
#
# 3. **Billie Holiday – All of Me**
#    빌리 할리데이의 독보적인 음색이 돋보이는 재즈 스탠다드.
#
# 4. **Nat King Cole – L-O-V-E**
#    누구나 따라 부를 수 있을 만큼 익숙하고 사랑스러운 곡입니다.
#
# 5. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
#    재즈 듀엣의 진수를 보여주는 곡!
#
# 6. **Duke Ellington – In a Sentimental Mood**
#    깊은 감성과 고급스러운 분위기를 연출하는 명곡.
#
# 7. **John Coltrane – In a Sentimental Mood**
#    아름다운 색소폰의 울림으로 듣는 이들의 귀를 사로잡습니다.
#
# 8. **Nina Simone – Feeling Good**
#    파워풀한 보컬과 멋진 그루브로 분위기를 확 바꾸고 싶을 때 추천!
#
# 9. **Miles Davis – Blue in Green**
#    조용히 분위기에 흠뻑 취하고 싶은 시간에 어울려요.
#
# 10. **Dave Brubeck – Take Five**
#    재즈 특유의 변칙 리듬이 멋진 대표곡으로, 항상 많은 신청을 받는 곡입니다.
#
# 이 곡들 중에서 선택한다면 진정한 '재즈바 인기쟁이'가 되실 거예요!

# %%
import asyncio
import time

messages = [("system", "당신은 음악 추천을 해주는 전문 AI입니다."),
            ("human", "재즈바에서 신청하면 인기쟁이 되는 재즈 10곡만 추천해줘.")]

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %%
print("Async")
start = time.perf_counter()
await invoke_parallel(llm, messages)
end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Async
# 물론이죠! 재즈바에서 분위기도 살리고, 진정한 '인기쟁이'가 될 수 있는 스탠더드 명곡 10곡을 아래에 추천합니다. 모두 재즈 팬들에게 사랑받는 곡으로, 신청하면 박수 받을 확률 100%입니다.
#
# 1. **Autumn Leaves** – Joseph Kosma
# 2. **All of Me** – Gerald Marks & Seymour Simons
# 3. **My Favorite Things** – Richard Rodgers & Oscar Hammerstein II
# 4. **Take Five** – Dave Brubeck
# 5. **Fly Me to the Moon** – Bart Howard
# 6. **Blue Monk** – Thelonious Monk
# 7. **Misty** – Erroll Garner
# 8. **The Girl from Ipanema (Garota de Ipanema)** – Antônio Carlos Jobim
# 9. **Moanin’** – Bobby Timmons (Art Blakey & The Jazz Messengers)
# 10. **Cantaloupe Island** – Herbie Hancock
#
# 이 곡들 중에서 한 곡 신청하면, 멋진 분위기와 함께 주목받을 거예요!
# 재즈바에서 신청하면 분위기를 띄우고, 많은 사람들이 좋아할 만한 인기 재즈 곡 10곡을 추천해드립니다! 클래식부터 모던까지, 재즈 팬들과 초심자 모두의 귀를 사로잡는 곡들입니다.
#
# 1. **Chet Baker – My Funny Valentine**
#    감미로운 트럼펫과 목소리가 분위기를 담백하게 만들어줍니다.
#
# 2. **Miles Davis – So What**
#    재즈의 명곡. 모던 재즈를 대표하는 쿨한 사운드로, 누구나 고개를 끄덕이게 돼요.
#
# 3. **Bill Evans – Waltz for Debby**
#    부드러우면서도 멜로딕한 피아노 트리오의 정석.
#
# 4. **Duke Ellington – In a Sentimental Mood**
#    재즈바의 밤 분위기에 딱 어울리는 곡이죠.
#
# 5. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
#    두 전설의 듀엣, 듣기만 해도 미소 짓게 만듭니다.
#
# 6. **John Coltrane – Naima**
#    소울풀한 색소폰이 깊은 여운을 줍니다.
#
# 7. **Frank Sinatra – Fly Me to the Moon**
#    여전히 많은 사랑을 받는 스탠다드 곡!
#
# 8. **Norah Jones – Don't Know Why**
#    재즈바에서도 자주 들을 수 있는 모던 재즈/팝 교차점.
#
# 9. **Dave Brubeck – Take Five**
#    독특한 리듬과 쿨한 멜로디는 모두를 흥얼거리게 만들어줍니다.
#
# 10. **Jamie Cullum – Everlasting Love**
#     젊은 감성의 현대 재즈곡으로 분위기에 활기를 더해줍니다.
#
# 이 곡들 신청하시면, 재즈바에서 인기쟁이가 되는 건 시간문제예요!
# 재즈바에서 신청하면 분위기를 띄우고, 모두에게 사랑받는 클래식 명곡들 위주로 10곡을 엄선했습니다. 다양한 시대와 스타일을 골고루 섞어서 준비했으니, 신청하시면 분명 인기쟁이가 될 수 있어요!
#
# 1. **Autumn Leaves** – Cannonball Adderley
#    (또는 Chet Baker, Eva Cassidy 등 다양한 버전으로도 인기)
#
# 2. **Blue Monk** – Thelonious Monk
#
# 3. **Take Five** – Dave Brubeck Quartet
#
# 4. **My Favorite Things** – John Coltrane
#
# 5. **All of Me** – Billie Holiday
#    (Frank Sinatra, Louis Armstrong 등도 인기)
#
# 6. **Fly Me to the Moon** – Frank Sinatra
#    (피아노 재즈 트리오로도 자주 연주되는 곡)
#
# 7. **Cheek to Cheek** – Ella Fitzgerald & Louis Armstrong
#
# 8. **Cantaloupe Island** – Herbie Hancock
#
# 9. **The Girl from Ipanema** – Stan Getz & João Gilberto
#    (보사노바 재즈의 대표곡!)
#
# 10. **So What** – Miles Davis
#
# 이 곡들은 초보부터 찐 애호가까지 모두가 환호할, 재즈바 단골 곡입니다.
# 즐거운 재즈 타임 보내세요!
# 물론이죠! 재즈바에서 신청하면 분위기도 살리고 모두의 관심을 받을 수 있는 대표적이고 인기 많은 재즈곡 10곡을 엄선해서 추천드릴게요.
#
# 1. **Fly Me To The Moon – Frank Sinatra**
#    - 달콤한 분위기와 누구에게나 익숙한 멜로디의 스탠더드 곡.
#
# 2. **Autumn Leaves – Cannonball Adderley, Miles Davis**
#    - 감성적인 선율로 가을 뿐 아니라 언제 들어도 몽환적인 곡.
#
# 3. **Take Five – Dave Brubeck Quartet**
#    - 독특한 5/4 박자의 리듬과 경쾌함이 매력적인 재즈 대표곡.
#
# 4. **Blue Bossa – Joe Henderson**
#    - 보사노바 리듬을 가미해 분위기 전환에 딱 좋은 재즈 넘버.
#
# 5. **All of Me – Billie Holiday**
#    - 흥겨우면서 누구나 따라부르기 쉬운 곡.
#
# 6. **My Favorite Things – John Coltrane**
#    - 익숙한 멜로디와 화려한 색소폰 솔로가 돋보여요.
#
# 7. **L.O.V.E – Nat King Cole**
#    - 자연스럽게 흥얼거리게 되는 기분 좋은 러브송.
#
# 8. **Cantaloupe Island – Herbie Hancock**
#    - 그루브 넘치는 멋진 피아노와 밴드 사운드.
#
# 9. **Cheek To Cheek – Ella Fitzgerald & Louis Armstrong**
#    - 남녀 듀엣의 아름다운 화음과 리듬이 매력적인 곡.
#
# 10. **So What – Miles Davis**
#     - 모던 재즈의 대표작. 고급스러운 분위기 연출에 최고.
#
# 이 곡들 중 하나를 직접 신청하면 분위기와 반응 모두 확실히 즐거워질 거예요!
# 물론이죠! 재즈바에서 분위기를 띄우고, 세련된 취향으로 인정받을 만한 인기 재즈 명곡 10곡을 추천해 드릴게요.
#
# **재즈바 인기곡 10선**
#
# 1. **Chet Baker – My Funny Valentine**
#    감미로운 트럼펫과 목소리가 분위기를 끌어올립니다.
#
# 2. **Bill Evans – Waltz for Debby**
#    아름다운 피아노 연주로 많은 사람들이 사랑하는 곡입니다.
#
# 3. **John Coltrane – In a Sentimental Mood (with Duke Ellington)**
#    색소폰과 피아노가 어우러진 우아한 곡입니다.
#
# 4. **Stan Getz & João Gilberto – The Girl from Ipanema**
#    보사노바와 재즈의 만남, 모두가 좋아하는 명곡이죠.
#
# 5. **Miles Davis – Blue in Green**
#    섬세한 연주와 잔잔한 분위기로 특히 밤에 잘 어울립니다.
#
# 6. **Dave Brubeck – Take Five**
#    재즈의 스탠더드, 독특한 리듬으로 모두가 귀를 기울입니다.
#
# 7. **Ella Fitzgerald & Louis Armstrong – Dream a Little Dream of Me**
#    따뜻하고 편안한 듀엣으로 분위기를 한층 부드럽게 해줍니다.
#
# 8. **Diana Krall – The Look of Love**
#    재즈바에서 자주 신청되는 현대 재즈 보컬 곡입니다.
#
# 9. **Art Blakey & the Jazz Messengers – Moanin’**
#    파워풀하고 그루브한 곡으로 기분을 업시켜줍니다.
#
# 10. **Nina Simone – Feeling Good**
#     독보적인 보컬과 카리스마, 모두의 감탄을 불러일으키죠.
#
# 이 곡들로 재즈바에서 센스 있는 인기 신청자가 되어보세요!
# 물론이죠! 재즈바에서 신청하면 분위기와 취향 모두 잡을 수 있는, 인기 있는 재즈 곡 10곡을 추천해 드릴게요. 클래식한 스탠더드부터, 분위기 있는 곡 위주로 골라봤어요.
#
# 1. Chet Baker – **My Funny Valentine**
# 2. Bill Evans Trio – **Waltz for Debby**
# 3. Ella Fitzgerald & Louis Armstrong – **Summertime**
# 4. Duke Ellington – **In a Sentimental Mood**
# 5. Miles Davis – **Blue in Green**
# 6. Norah Jones – **Don’t Know Why**
# 7. John Coltrane – **Naima**
# 8. Oscar Peterson – **C Jam Blues**
# 9. Stan Getz & João Gilberto – **The Girl from Ipanema**
# 10. Nat King Cole – **L-O-V-E**
#
# 이 곡들은 재즈바에서 자주 연주/신청되고, 누구나 쉽게 즐길 수 있는 명곡들이예요.
# 선곡만 잘 해도 분위기 메이커가 될 거예요!
# 물론이죠! 재즈바에서 신청하면 분위기를 확 살리면서도 많은 사람들의 사랑을 받는 클래식하고 친숙한 재즈 곡 10곡을 골라봤어요. 모두 유명한 곡들이라 신청하면 인기 폭발할 거예요!
#
# 1. **Autumn Leaves** – Chet Baker (혹은 Cannonball Adderley, Bill Evans 버전도 추천)
# 2. **Take Five** – Dave Brubeck Quartet
# 3. **My Favorite Things** – John Coltrane
# 4. **All of Me** – Billie Holiday
# 5. **What a Wonderful World** – Louis Armstrong
# 6. **Fly Me to the Moon** – Frank Sinatra (혹은 Tony Bennett, Julie London 버전)
# 7. **The Girl From Ipanema** – Stan Getz & João Gilberto
# 8. **Misty** – Erroll Garner
# 9. **Night and Day** – Cole Porter
# 10. **So What** – Miles Davis
#
# 이 곡들은 대중적이면서도 감미롭거나 스윙감 있는 재즈의 매력을 잘 보여주니, 재즈바에서 분위기 메이커가 되기에 딱이에요!
# 물론이죠! 재즈바에서 신청하면 분위기와 센스를 모두 인정받을 수 있는 인기 재즈 곡 10곡을 추천해드릴게요. 클래식부터 모던까지, 다양한 스타일로 골라봤어요.
#
# 1. **Chet Baker – My Funny Valentine**
# 재즈바에서 절대 빠질 수 없는 감미로운 트럼펫과 목소리.
#
# 2. **Miles Davis – Blue in Green**
# 감성적인 밤에 어울리는 명곡.
#
# 3. **John Coltrane – In a Sentimental Mood**
# 따뜻하고 깊은 서정이 흐르는 명연주.
#
# 4. **Stan Getz & João Gilberto – The Girl from Ipanema**
# 이국적인 보사노바 리듬으로 분위기 up!
#
# 5. **Duke Ellington – In a Mellow Tone**
# 경쾌하면서도 부드러운 빅밴드 사운드.
#
# 6. **Bill Evans – Waltz for Debby**
# 피아노 트리오의 섬세함이 살아있는 곡.
#
# 7. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
# 재즈 스탠다드의 달콤한 듀엣.
#
# 8. **Charles Mingus – Moanin'**
# 블루지하고 그루비한 사운드로 흥을 돋움.
#
# 9. **Herbie Hancock – Cantaloupe Island**
# 현대적인 감각의 재즈 펑크.
#
# 10. **Norah Jones – Don't Know Why**
# 재즈바에서 종종 듣는 세련된 목소리의 팝 재즈.
#
# 이 곡들 중 골라서 재즈바에서 신청하면, 분명 분위기가 한층 좋아질 거예요!
# 물론이죠! 재즈바 분위기에 어울리면서도 모두가 좋아할 만한, 클래식하면서 인기가 많은 재즈 곡 10곡을 엄선해 추천해드릴게요.
#
# 1. **Chet Baker – My Funny Valentine**
# 감미로운 트럼펫과 보컬이 매력적인 곡. 늘 사랑받는 재즈 스탠다드예요.
#
# 2. **Bill Evans – Waltz for Debby**
# 잔잔하고 서정적인 피아노 연주가 돋보여서 분위기 잡기에 딱이죠.
#
# 3. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
# 두 레전드가 함께 부른 이 곡은 언제 들어도 행복해지는 명곡입니다.
#
# 4. **John Coltrane – In a Sentimental Mood (with Duke Ellington)**
# 감성을 가득 채워주는 아름다운 색소폰과 피아노의 만남.
#
# 5. **Nat King Cole – L-O-V-E**
# 클래식하면서도 경쾌해서 누구나 기분 좋아지는 곡이에요.
#
# 6. **Miles Davis – So What**
# 쿨하고 시크한 무드의 재즈. 분위기 전환에 완벽합니다.
#
# 7. **Frank Sinatra – Fly Me to the Moon**
# 세련되고 여유로운 스윙 재즈의 대표곡.
#
# 8. **Sarah Vaughan – Misty**
# 깊고 감미로운 목소리로 많은 이들의 사랑을 받는 곡.
#
# 9. **Stan Getz & João Gilberto – The Girl from Ipanema**
# 보사노바와 재즈의 랑데부. 남녀노소 모두에게 익숙한 멜로디예요.
#
# 10. **Duke Ellington – Take the "A" Train**
# 재즈바라면 한번쯤 꼭 나오는, 빼놓을 수 없는 빅밴드 재즈!
#
# 이 곡들을 플레이리스트에 넣고 신청하면, 재즈바의 인기쟁이가 되는 건 시간문제일 거예요!
# 물론이죠! 재즈바에서 신청하면 분위기를 한껏 업시키고, 센스 있다고 칭찬받을 만한 인기 재즈 곡 10곡을 추천해드릴게요.
#
# 1. **Chet Baker – "My Funny Valentine"**
# 감미로운 트럼펫과 목소리로 재즈 입문자와 마니아 모두에게 사랑받는 곡.
#
# 2. **Bill Evans – "Waltz for Debby"**
# 포근한 피아노 사운드로 바의 분위기를 따뜻하게 만들어주는 명곡.
#
# 3. **John Coltrane – "In a Sentimental Mood"**
# 색소폰의 깊은 감성이 흐르는, 로맨틱하고 세련된 분위기.
#
# 4. **Miles Davis – "So What"**
# 쿨 재즈의 대표곡. 세련되고 세심한 감성이 돋보여요.
#
# 5. **Ella Fitzgerald & Louis Armstrong – "Summertime"**
# 듀엣의 하모니가 재즈바의 밤을 더 아름답게 만들어줍니다.
#
# 6. **Duke Ellington – "Take the 'A' Train"**
# 경쾌한 빅밴드 사운드로 공간에 활기를 불어넣는 곡.
#
# 7. **Stan Getz & João Gilberto – "The Girl from Ipanema"**
# 보사노바 리듬으로 이국적인 낭만까지 선사해요.
#
# 8. **Charles Mingus – "Moanin'"**
# 블루지하면서도 에너지 넘치는 사운드로 깊은 인상을 남깁니다.
#
# 9. **Nina Simone – "Feeling Good"**
# 유니크한 보컬이 주는 자유와 희망의 에너지!
#
# 10. **Dave Brubeck – "Take Five"**
# 재즈바에서 빠질 수 없는 재즈 스탠다드, 독특한 5박자 리듬이 인상적이에요.
#
# 이 곡들로 재즈바의 분위기를 한층 업그레이드해보세요!
# Elapsed time: 17.63 seconds

# %%
print("Sync")
start = time.perf_counter()
for i in range(10):
    response = llm.invoke(messages)
    print(response.content)
    print()

end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Sync
# 물론이죠! 재즈바에서 신청하면 모두의 주목을 받는, 분위기를 확실히 띄워줄 재즈 명곡 10곡을 추천해드릴게요.
#
# 1. **Take Five** – Dave Brubeck Quartet
#    대중적으로 가장 사랑받는 쿨 재즈의 대명사!
#
# 2. **Autumn Leaves** – Cannonball Adderley with Miles Davis
#    가을밤 감성 자극! 신청곡 1순위입니다.
#
# 3. **So What** – Miles Davis
#    모던 재즈의 교과서 같은 곡, 누구나 안다면 고개를 끄덕이는 명곡!
#
# 4. **All of Me** – Billie Holiday
#    부드러운 보컬 곡을 좋아한다면 반드시 신청해야 할 곡.
#
# 5. **Fly Me to the Moon** – Frank Sinatra
#    재즈바에서 빠질 수 없는 분위기 제조기.
#
# 6. **Cantaloupe Island** – Herbie Hancock
#    쿨한 그루브와 도입부의 피아노가 모두의 귀를 사로잡습니다.
#
# 7. **My Funny Valentine** – Chet Baker
#    감성적인 밤, 미성의 트럼펫/보컬이 관객의 마음에도 잔잔한 파동을 남깁니다.
#
# 8. **Girl from Ipanema** – Stan Getz & João Gilberto
#    보사노바 풍의 재즈 넘버, 여름 밤 분위기에 제격!
#
# 9. **Round Midnight** – Thelonious Monk
#    깊은 밤의 재즈, 진한 감동과 여운을 남깁니다.
#
# 10. **Blue Monk** – Thelonious Monk
#      재즈 피아노 스타일의 정수를 보여주는 블루지한 명곡.
#
# 이 곡들 중 하나를 신청하면, 여러분은 단번에 ‘재즈 잘 아는 사람’이 될 수 있습니다!
#
# 재즈바에서 신청하기 좋고, 모두가 좋아할 만한 재즈 명곡 10곡을 추천해드릴게요. 분위기를 확 살려줄 스탠더드 곡들로 골랐습니다!
#
# 1. **Louis Armstrong – What a Wonderful World**
#    재즈바에서 빠질 수 없는 명곡, 누구나 따라부르기 좋은 곡입니다.
#
# 2. **Chet Baker – My Funny Valentine**
#    감미로운 트럼펫과 목소리가 분위기를 한층 로맨틱하게 만들어줍니다.
#
# 3. **Duke Ellington – In A Sentimental Mood**
#    잔잔하고 우아한 피아노가 돋보이는 대표적인 재즈 발라드입니다.
#
# 4. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
#    듣기만 해도 기분 좋아지는 듀엣곡, 기분이 업되는 순간에 딱이죠.
#
# 5. **Miles Davis – So What**
#    모던 재즈의 교과서 같은 명곡, 재즈 팬들 사이에서 인기 만점입니다.
#
# 6. **Frank Sinatra – Fly Me to the Moon**
#    스윙감이 돋보이는 신나는 곡으로, 신청곡으로 매우 인기 많아요.
#
# 7. **Bill Evans – Waltz for Debby**
#    감성적인 피아노 재즈, 분위기를 고급스럽게 만들어줍니다.
#
# 8. **Stan Getz & João Gilberto – The Girl from Ipanema**
#    보사노바 재즈의 대표곡, 이국적인 분위기를 연출할 때 최고!
#
# 9. **John Coltrane – Blue Train**
#    에너지 넘치는 하드밥 트랙으로, 재즈 마니아들도 즐기는 곡입니다.
#
# 10. **Charlie Parker – All The Things You Are**
#     재즈 스탠더드의 정석, 연주버전이나 보컬버전 모두 인기 많아요.
#
# 이 곡들 신청하면 재즈바에서 분위기 메이커가 될 수 있을 거예요!
#
# 물론이죠! 재즈바에서 신청하면 분위기도 살리고 “센스 있네” 소리 듣는 인기 재즈 넘버 10곡 추천드립니다.
#
# 1. **Chet Baker – My Funny Valentine**
#    감미로운 트럼펫과 보컬로 재즈바 단골 신청곡입니다.
#
# 2. **Bill Evans – Waltz for Debby**
#    여유로운 피아노 트리오의 정수! 분위기 최고.
#
# 3. **Miles Davis – So What**
#    모던 재즈의 상징이죠. 묵직한 쿨함.
#
# 4. **John Coltrane – In a Sentimental Mood**
#    색소폰의 낭만이 한가득.
#
# 5. **Nina Simone – Feeling Good**
#    재즈와 소울이 절묘하게 섞인 명곡.
#
# 6. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
#    두 레전드의 달콤한 듀엣, 분위기 확살려줍니다.
#
# 7. **Stan Getz & João Gilberto – The Girl from Ipanema**
#    보사노바의 대명사, 여름밤엔 이만한 게 없죠!
#
# 8. **Duke Ellington – In a Sentimental Mood**
#    재즈의 클래식, 언제 들어도 좋습니다.
#
# 9. **Diana Krall – Fly Me to the Moon**
#    팝과 재즈 팬 모두 만족시키는 현대 재즈의 아이콘 곡.
#
# 10. **Dave Brubeck – Take Five**
#     신나는 5박자 리듬! 누구나 아는 멜로디.
#
# 이 곡들 중 하나만 신청해도 재즈바 분위기를 쫙 띄워줄 거예요. 즐거운 재즈 타임 되세요!
#
# 재즈바에서 신청하면 분위기를 업그레이드해주면서도 모두에게 사랑받는, 인기쟁이 예약 재즈 10곡을 엄선해서 추천해드릴게요!
#
# 1. **Chet Baker – My Funny Valentine**
# 2. **Billie Holiday – All of Me**
# 3. **Frank Sinatra – Fly Me to the Moon**
# 4. **Stan Getz & João Gilberto – The Girl from Ipanema**
# 5. **Miles Davis – So What**
# 6. **Diana Krall – The Look of Love**
# 7. **Antonio Carlos Jobim – Desafinado**
# 8. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
# 9. **Duke Ellington – In a Sentimental Mood**
# 10. **Nat King Cole – L-O-V-E**
#
# 이 곡들은 재즈바의 클래식한 분위기도 살리면서 남녀노소에게 무리 없이 어필할 수 있는 곡들이에요. 신청하면 ‘취향 좀 아네?’라는 소리 들으실 거예요!
#
# 물론이죠! 재즈바에서 신청하면 분위기를 확 살리고, 다른 사람들에게도 좋은 인상을 남길 수 있는 인기 재즈 명곡 10곡을 추천드립니다.
#
# 1. Chet Baker – "My Funny Valentine"
# 2. Bill Evans – "Waltz for Debby"
# 3. Miles Davis – "So What"
# 4. John Coltrane – "In a Sentimental Mood" (with Duke Ellington)
# 5. Ella Fitzgerald & Louis Armstrong – "Dream a Little Dream of Me"
# 6. Frank Sinatra – "Fly Me to the Moon"
# 7. Norah Jones – "Don't Know Why"
# 8. Antonio Carlos Jobim – "The Girl from Ipanema"
# 9. Herbie Hancock – "Cantaloupe Island"
# 10. Dave Brubeck – "Take Five"
#
# 이 곡들은 분위기도 좋고, 재즈에 익숙하지 않은 사람들도 많이 아는 스탠더드 위주라서, 신청곡으로 부르면 분명 인기쟁이가 되실 거예요!
#
# 물론이죠! 재즈바에서 신청하면 분위기도 살리고, 센스 있다는 소리 듣기 좋은 재즈 명곡 10곡을 엄선해봤어요.
#
# 1. **Chet Baker - My Funny Valentine**
# 감미로운 트럼펫과 보컬, 누구나 좋아하는 재즈 스탠다드입니다.
#
# 2. **Bill Evans Trio - Waltz for Debby**
# 재즈 피아노의 아름다움을 느낄 수 있는 명곡이에요.
#
# 3. **Duke Ellington - In A Sentimental Mood**
# 로맨틱하고 세련된 밤을 만들어주는 클래식입니다.
#
# 4. **Stan Getz & João Gilberto - The Girl from Ipanema**
# 보사노바와 재즈가 어우러진, 늘 사랑받는 곡이에요.
#
# 5. **Nina Simone - Feeling Good**
# 파워풀한 보컬과 소울풀한 분위기가 일품입니다.
#
# 6. **John Coltrane - Blue Train**
# 재즈 애호가들에게 인기만점인 하드밥 대표곡이에요.
#
# 7. **Miles Davis - So What**
# 쿨 재즈의 대표적 곡, 재즈바와 완벽하게 어울립니다.
#
# 8. **Ella Fitzgerald & Louis Armstrong - Dream a Little Dream of Me**
# 두 거장의 환상적인 하모니로 듣는 스탠다드 곡이에요.
#
# 9. **Nat King Cole - L-O-V-E**
# 기분 좋은 밤을 만들어주는 달달한 재즈 넘버입니다.
#
# 10. **Herbie Hancock - Cantaloupe Island**
# 모던하면서도 그루브한, 분위기를 띄우기 좋은 곡이에요.
#
# 이 곡들로 신청하면 재즈바의 인기인 될 수 있을 거예요!
#
# 물론이죠! 재즈바에서 신청하면 분위기와 센스를 모두 챙길 수 있는 인기 재즈 곡 10곡을 추천해드릴게요.
#
# 1. **Take Five** – Dave Brubeck
#    독특한 5/4 박자와 캐치한 멜로디로 세계적으로 사랑받는 곡.
#
# 2. **Autumn Leaves** – Cannonball Adderley (feat. Miles Davis)
#    낭만적이고 서정적인 멜로디가 분위기를 살려줍니다.
#
# 3. **All of Me** – Billie Holiday
#    누구나 아는 스탠더드곡! 빌리 할리데이의 감성으로 들으면 더욱 매력적이죠.
#
# 4. **Blue in Green** – Miles Davis
#    잔잔하면서도 깊은 울림이 있는 명곡.
#
# 5. **Fly Me to the Moon** – Frank Sinatra
#    스윙 재즈의 대표곡으로 언제 들어도 기분 좋은 곡입니다.
#
# 6. **My Favorite Things** – John Coltrane
#    원곡과는 또 다른 감성의 재즈 버전, 색소폰 소리가 인상적이에요.
#
# 7. **The Girl from Ipanema** – Stan Getz & João Gilberto
#    보사노바 리듬으로 느긋하고 로맨틱한 분위기 연출에 제격.
#
# 8. **Cantaloupe Island** – Herbie Hancock
#    모던하면서도 그루브한 느낌이 매력적인 곡.
#
# 9. **Cheek to Cheek** – Ella Fitzgerald & Louis Armstrong
#    달콤하고 경쾌한 듀엣의 조화가 매우 사랑받는 곡입니다.
#
# 10. **Round Midnight** – Thelonious Monk
#    독특한 하모니와 느긋한 템포로 깊은 감동을 주는 재즈 명곡.
#
# 이 곡들 중에서 신청하면, 재즈에 대해 잘 아는 센스 있는 사람으로 보일 거예요!
#
# 물론이죠! 재즈바에서 신청하면 분위기도 살리고, 주변의 이목을 끌 수 있는 인기 재즈 명곡 10곡을 엄선해서 추천합니다.
#
# 1. **Chet Baker - My Funny Valentine**
#    감미로운 트럼펫, 로맨틱한 분위기를 좋아하는 이들에게 제격이죠.
#
# 2. **Bill Evans Trio - Waltz for Debby**
#    재즈 팬이라면 누구나 사랑하는 고전 피아노 트리오 명곡입니다.
#
# 3. **John Coltrane - In a Sentimental Mood (with Duke Ellington)**
#    센티멘털한 감성을 자아내는 절대적 명작이에요.
#
# 4. **Miles Davis - So What**
#    모던재즈의 상징적인 피스, 머리를 끄덕이며 흐느적거리기 딱 좋습니다.
#
# 5. **Nina Simone - Feeling Good**
#    재즈바에서 분위기 반전시키고 싶을 때 최고의 선택!
#
# 6. **Dave Brubeck - Take Five**
#    5/4 박자의 독특한 리듬이 공간을 세련되게 물들입니다.
#
# 7. **Frank Sinatra - Fly Me to the Moon**
#    재즈바라면 절대 빠질 수 없는 ‘스탠더드’ 중의 스탠더드.
#
# 8. **Ella Fitzgerald & Louis Armstrong - Dream a Little Dream of Me**
#    달달하고 기분 좋아지는 듀엣 명곡이에요.
#
# 9. **Charles Mingus - Moanin'**
#    그루브와 에너지가 폭발하는 곡, 분위기 업에 최고입니다.
#
# 10. **Norah Jones - Don't Know Why**
#     올드와 모던이 어우러진 감성, 모두가 좋아할만한 곡이죠.
#
# 이 곡들로 신청 리스트를 꾸리면 음악 센스 있는 사람으로 주목받으실 거예요. 분위기에 맞게 골라 신청해보세요!
#
# 재즈바에서 분위기를 띄우고, 주변 사람들의 관심을 한껏 받을 수 있는 "인기쟁이" 재즈 10곡을 아래에 추천합니다. 재즈 애호가뿐 아니라 누구나 즐길 수 있는 스탠다드와 분위기 좋은 명곡들로 골라봤어요!
#
# 1. **Chet Baker – My Funny Valentine**
# 감미로운 트럼펫과 목소리가 인상적인, 재즈바에서 빠지지 않는 명곡.
#
# 2. **Bill Evans – Waltz for Debby**
# 피아노 트리오의 따스한 감성이 가득한 곡. 세련된 분위기에 잘 어울림.
#
# 3. **Miles Davis – So What**
# 쿨 재즈 대표곡. 유명한 인트로와 함께 분위기가 단번에 살아납니다.
#
# 4. **Ella Fitzgerald & Louis Armstrong – Cheek to Cheek**
# 남녀 보컬 듀엣의 매력이 돋보이는 스윙 넘버.
#
# 5. **John Coltrane – In a Sentimental Mood**
# 달콤하면서도 우아한 색소폰 연주로 듣는 이의 마음을 사로잡는 곡.
#
# 6. **Duke Ellington – Take the "A" Train**
# 재즈 애호가들이라면 다 아는 경쾌한 스윙 곡.
#
# 7. **Stan Getz & João Gilberto – The Girl from Ipanema**
# 부드러운 보사노바와 재즈의 만남. 누구나 알고 있는 대표적인 곡.
#
# 8. **Norah Jones – Don't Know Why**
# 모던 재즈와 팝의 경계, 누구나 편하게 즐길 수 있는 곡.
#
# 9. **Frank Sinatra – Fly Me to the Moon**
# 재즈바, 피아노 바에서 가장 인기 있는 스탠다드 보컬 곡 중 하나.
#
# 10. **Charles Mingus – Moanin’**
# 블루지하고 파워풀한, 분위기에 확실한 변화를 주고 싶을 때 추천!
#
# ---
#
# 이 곡들 중 하나를 신청하면 ‘센스 있다’는 소리와 함께 인기쟁이가 될 수 있을 거예요!
#
# 당연하죠! 재즈바에서 신청했을 때 분위기를 확 살려주는, 많은 사람들이 좋아하고 분위기 있는 인기 재즈 10곡을 추천해드릴게요.
#
# ### 1. **Autumn Leaves – Chet Baker 버전**
# 감성적인 트럼펫과 목소리가 어우러져 누구나 좋아하는 스탠더드 곡이에요.
#
# ### 2. **Take Five – The Dave Brubeck Quartet**
# 5박자의 독특한 리듬과 쿨한 분위기로 재즈 팬들에게 늘 사랑받죠.
#
# ### 3. **Fly Me to the Moon – Frank Sinatra**
# 누구나 한 번쯤 들어본 곡, Sinatra의 목소리가 분위기를 UP!
#
# ### 4. **All of Me – Billie Holiday**
# 시원하고 연인이 함께 들으면 참 좋은 스윙 넘버예요.
#
# ### 5. **Blue Bossa – Kenny Dorham**
# 부드러운 보사노바 리듬과 즉흥 연주가 멋진 곡입니다.
#
# ### 6. **My Favorite Things – John Coltrane**
# 우리 모두에게 친숙한 멜로디를 Coltrane 특유의 색소폰으로 재해석한 작품.
#
# ### 7. **What a Wonderful World – Louis Armstrong**
# 따뜻한 감성과 특유의 음색으로 언제 들어도 마음이 포근해집니다.
#
# ### 8. **Lullaby of Birdland – Sarah Vaughan**
# 달콤하면서도 활기찬 분위기, 재즈바에서 아주 사랑받는 곡입니다.
#
# ### 9. **So What – Miles Davis**
# 모던 재즈의 상징 같은 명곡, 적당히 감각적이면서 스타일리시해요.
#
# ### 10. **Moanin’ – Art Blakey & The Jazz Messengers**
# 소울풀한 블루스 감성과 독특한 피아노 리프가 멋진 곡입니다.
#
# ---
# 이 리스트에서 한 곡만 신청해도 분위기 잡기 딱 좋아요!
# 재즈바에서 인기쟁이 되세요 :)
#
# Elapsed time: 96.54 seconds

# %%
from langchain.memory import ChatMessageHistory

memory = ChatMessageHistory()

memory.add_message(SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다'))
memory.add_user_message('부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.')

response = llm.invoke(memory.messages)
memory.add_ai_message(response.content)
for msg in memory.messages:
    print(type(msg), msg)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 단 한 곳만 가야 한다면 저는 **해운대 해수욕장**을 추천드립니다.\n\n**이유:**\n- 부산을 대표하는 상징적인 바닷가입니다.\n- 넓고 깨끗한 백사장, 탁 트인 푸른 바다, 활기찬 분위기를 느낄 수 있습니다.\n- 해운대 주변에 고급 호텔, 카페, 레스토랑, 영화의전당 등 다양한 즐길 거리가 모여 있어 알찬 시간 보내기에 좋습니다.\n- 특히 동백섬, 해운대 블루라인파크(해변열차/스카이캡슐), 더베이 101 등과 가까워 산책과 사진 촬영, 맛집 탐방 등도 추가로 즐길 수 있습니다.\n- 계절을 막론하고 부산의 활기와 낭만, 해안 도시의 특별한 분위기를 가장 잘 느낄 수 있는 곳입니다.\n\n**아침, 낮, 일몰, 밤 모두 아름다운 매력을 지니고 있으니** 일정이 허락된다면 넉넉히 시간을 잡아 방문해 보세요!' additional_kwargs={} response_metadata={}

# %%
messages = [("system", "당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다")]

msg = ['부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.',
       '그리고 그 곳에서 먹을 수 있는 음식을 추천해주세요.',
       '근처에 있는 다른 곳을 추천해주세요.']

for m in msg:
    messages.append(HumanMessage(content=f"'user': {m}"))
    response = llm.invoke(messages)
    messages.append(response)
    print(response.content)
# Out:
# 정말 한 곳만 추천해야 한다면 **해운대 해수욕장**을 추천합니다.
#
# 이유는 다음과 같습니다:
#
# - 부산을 대표하는 랜드마크이자, 탁 트인 바다 풍경과 백사장이 아름답습니다.
# - 근처에는 해운대 블루라인 파크(해변 열차), 동백섬, 더베이 101, 다양한 카페와 맛집이 있어 짧은 일정에도 풍성한 경험이 가능합니다.
# - 바다 산책, 일몰 감상, 시원한 바닷바람 등 부산의 ‘핵심적인 매력’을 한 번에 느낄 수 있는 장소입니다.
#
# 해운대 한 곳에서만 머무르더라도 부산의 볼거리, 먹거리, 분위기를 제대로 만끽하실 수 있습니다!
# 해운대에서 꼭 맛봐야 할 대표 음식은 **해운대 밀면**입니다.
#
# 밀면은 부산을 대표하는 시원하고 쫄깃한 국수 요리로, 특히 해운대에는 오랜 전통을 자랑하는 유명 밀면집들이 모여 있습니다. 탱탱한 면발에 시원한 육수, 매콤한 양념이 어우러져 바닷가에서 먹으면 더욱 별미랍니다.
#
# 추가로 해운대에서는 다음 음식도 추천드려요.
#
# - **해산물(회, 조개구이):** 해운대 시장과 바닷가 주변에 싱싱한 횟집, 조개구이집이 많습니다.
# - **국밥(돼지국밥, 소고기국밥):** 부산의 또 다른 대표 음식으로, 든든한 한 끼로 좋습니다.
# - **튀김 분식(씨앗 호떡, 어묵):** 해운대 시장이나 포장마차에서 간편하게 즐기실 수 있어요.
#
# 만약 바다가 바로 보이는 뷰에서 식사를 원하신다면, 더베이 101이나 바닷가 앞 레스토랑, 카페도 한 번 들러보세요. 맛과 풍경, 부산의 분위기를 모두 느끼실 수 있을 거예요!
# 해운대와 가까운 곳 중에서 꼭 가볼 만한 곳 몇 군데를 추천해드릴게요!
#
# 1. **동백섬**
# - 해운대 바로 옆에 위치한 섬으로, 산책로가 잘 조성되어 있어 바다와 숲을 동시에 즐길 수 있습니다.
# - 누리마루 APEC하우스가 있어 부산의 바다를 한눈에 볼 수 있어요.
#
# 2. **더베이 101**
# - 해운대 바닷가 초입에 있는 핫플레이스! 야경이 아름답기로 유명하며, 요트 투어나 멋진 마리나 뷰를 감상하며 카페, 레스토랑을 즐길 수 있습니다.
#
# 3. **해운대 블루라인 파크(해변열차, 스카이캡슐)**
# - 해운대 미포에서 송정까지 이어지는 해변 열차와 스카이캡슐을 타면, 바닷가와 기찻길 위에서 인생사진을 남길 수 있습니다.
#
# 4. **송정 해수욕장**
# - 해운대에서 블루라인 파크 열차를 타고 갈 수 있는 또 다른 바닷가!
# - 해변이 비교적 한산하면서도, 서핑과 카페 거리로도 유명해 젊은 여행자에게 인기 많아요.
#
# 5. **해운대 전통시장**
# - 해운대 해변에서 도보로 가까우며, 다양한 부산 분식, 해산물, 회, 밀면, 씨앗호떡 등을 맛볼 수 있습니다.
#
# 이 중에서 동선을 짜시면 바다, 산책, 맛집, 체험 모두를 알차게 즐기실 수 있습니다!

# %%
from langchain.memory import ChatMessageHistory

memory = ChatMessageHistory()

memory.add_message(SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다'))

for m in msg:
    memory.add_user_message(m)
    response = llm.invoke(memory.messages)
    memory.add_ai_message(response.content)
    print(response.content)
# Out:
# 부산 여행에서 딱 한 곳만을 가봐야 한다면 **해운대 해수욕장**을 추천합니다.
#
# **이유:**
# - 부산을 대표하는 랜드마크로 넓은 백사장과 푸른 바다를 동시에 감상할 수 있습니다.
# - 주변에 맛집, 카페, 호텔, 쇼핑 등 다양한 즐길 거리가 밀집해 있습니다.
# - 해수욕뿐만 아니라 해안 산책로(동백섬, 더베이 101, 미포철길 등), 야경 감상도 가능합니다.
# - 부산의 활기찬 분위기와 바닷가의 낭만을 한 번에 만끽할 수 있습니다.
#
# **잠깐 TIP!**
# - 여름철에는 인파가 많으니 이른 아침이나 해질 무렵 방문하면 한적한 분위기와 멋진 풍경을 즐길 수 있습니다.
#
# 해운대 해수욕장 방문은 부산 여행의 진수를 느낄 수 있는 최고의 선택지입니다!
# 해운대에서 꼭 먹어봐야 할 음식은 **밀면**과 **회(생선회)**입니다.
#
# ---
#
# ### 1. 해운대 밀면
# - 부산을 대표하는 시원하고 쫄깃한 면요리!
# - 해운대에는 유명한 밀면 전문점들이 많아서, 가볍게 한 끼 하기 좋아요.
# - 추천 가게: **해운대 할매가야밀면**, **해운대소문난돼지국밥**(돼지국밥도 유명해요!)
#
# ### 2. 해운대 회센타의 신선한 회
# - 해운대 해수욕장 옆 **해운대시장**이나 **해운대 전통시장**,
# - 또는 **해운대 팔레드시즈 해변 앞에 있는 해운대시장**에서 직접 고른 활어를 즉석에서 즐길 수 있습니다.
# - 광어, 우럭 등 다양한 선어가 있으며, 회와 함께 나오는 매운탕까지 맛볼 수 있어요.
#
# ### 3. 그 외 먹거리
# - 바닷가에서 파는 **씨앗호떡**: 달콤하고 고소한 길거리 간식
# - **해산물 꼬치구이**: 해변 근처 포장마차에서 맛볼 수 있어요.
# - **해변 카페의 브런치와 디저트**: 바다 전망을 즐기며 가볍게 식사하기 좋습니다.
#
# ---
#
# **추천 코스 예시:**
# 해운대 백사장 산책 → 해운대시장 방문 → 신선한 회나 밀면으로 한 끼 → 바다 앞 카페에서 차 한 잔
#
# 특별한 부산의 맛을 제대로 느껴보세요!
# 해운대 해수욕장과 가까운 곳에서 함께 방문하기 좋은 인기 명소를 소개해드릴게요!
#
# ---
#
# ### 1. 동백섬 & 누리마루 APEC 하우스
# - 해운대 해수욕장에서 도보 10분 내외
# - 바다 위의 작은 섬으로, 산책로가 아름답고 부산의 멋진 바다 전망을 볼 수 있습니다.
# - 정상에는 한-아시아 정상회의가 열린 ‘누리마루 APEC 하우스’가 있어 관람 가능합니다.
#
# ### 2. 더베이 101
# - 해운대 해변 끝, 초고층 빌딩과 요트 선착장이 있는 핫플
# - 낮에는 요트 체험, 밤에는 환상적인 야경(마린시티와 해운대 빌딩 불빛을 배경으로 한 사진 스팟)으로 유명해요.
# - 카페·레스토랑도 많아 바다 보며 여유롭게 휴식 가능합니다.
#
# ### 3. 청사포 & 미포 철길 산책로
# - 해운대~청사포~송정까지 잇는 바닷가 산책로(구 해운대 미포 철길)
# - 해운대 미포 지역에서 산책로 입구를 따라 걷다보면 청사포, 송정까지 걸어서 이동할 수 있습니다(약 1시간)
# - 탁 트인 바다와 작은 기차역, 카페들이 있는 낭만적인 코스입니다.
#
# ### 4. 해운대 블루라인파크(해변열차/스카이캡슐)
# - 해운대 미포~청사포~송정까지 해변 따라 운행하는 레트로 열차
# - 바다를 가까이에서 느끼며 이동할 수 있어 가족, 연인, 친구 모두에게 인기
# - 스카이캡슐은 하늘 위에서 바다 전망을 즐길 수 있는 특별한 경험 제공
#
# ---
#
# **짧은 동선 추천**
# 해운대 해수욕장 → 동백섬 산책 → 더베이 101 야경 감상
# 혹은
# 해운대 해수욕장 → 미포 해변열차 혹은 산책로로 ‘청사포’까지 이동 → 카페나 포장마차에서 휴식
#
# 이렇게 해운대를 중심으로 한 부산의 대표적인 자연과 도시 풍경을 한 번에 즐길 수 있습니다!

# %% [markdown]
# ## Buffer Memory

# %%
from langchain.memory import ConversationBufferMemory 

memory = ConversationBufferMemory(memory_key="chat_history", 
                                return_messages=True)      
memory.clear() #기존에 저장된 모든 대화 내용을 초기화
memory.save_context({'human':'안녕하세요 챗봇님'},
                    {'bot':'안녕하세요! 반가워요, 호칭을 어떻게 하는게 좋을까요?'})
memory.save_context({'human':'나는 홍길동입니다'},
                    {'bot':'네, 홍길동님 만나서 반갑습니다'})
memory.save_context({'human':'경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요'},
                    {'bot':'물론이죠. 경복궁은 지하철을 타고 가면 편리합니다'}) 

result = memory.load_memory_variables({})
for msg in result['chat_history']:
    print(type(msg), msg)
# Out:
# <class 'langchain_core.messages.human.HumanMessage'> content='안녕하세요 챗봇님' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='안녕하세요! 반가워요, 호칭을 어떻게 하는게 좋을까요?' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='나는 홍길동입니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='네, 홍길동님 만나서 반갑습니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='물론이죠. 경복궁은 지하철을 타고 가면 편리합니다' additional_kwargs={} response_metadata={}
# C:\Users\JS\AppData\Local\Temp\ipykernel_28016\2478114211.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="chat_history",

# %% [markdown]
# ## Buffer Window Memory

# %%
from langchain.memory import ConversationBufferWindowMemory

#같은 메모리인데 최근 대화 k개를 가지고 있는 메모리
memory = ConversationBufferWindowMemory(memory_key="chat_history", 
                                        return_messages=True, 
                                        k=3) #최근 k개의 대화만 저장
memory.clear()
memory.save_context({'human':'안녕하세요 챗봇님'},
                    {'bot':'안녕하세요! 반가워요, 호칭을 어떻게 하는게 좋을까요?'}) #context의 시작은 항상 사용자
memory.save_context({'human':'나는 홍길동입니다'},
                    {'bot':'네, 홍길동님 만나서 반갑습니다'})
memory.save_context({'human':'경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요'},
                    {'bot':'물론이죠. 경복궁은 지하철을 타고 가면 편리합니다'})
memory.save_context({'human':'몇 호선을 타고 가야하는지 아니?'},
                    {'bot':'3호선을 타고 가세요'})  

result = memory.load_memory_variables({})
for msg in result['chat_history']:
    print(type(msg), msg)
# Out:
# <class 'langchain_core.messages.human.HumanMessage'> content='나는 홍길동입니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='네, 홍길동님 만나서 반갑습니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='물론이죠. 경복궁은 지하철을 타고 가면 편리합니다' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='몇 호선을 타고 가야하는지 아니?' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='3호선을 타고 가세요' additional_kwargs={} response_metadata={}
# C:\Users\JS\AppData\Local\Temp\ipykernel_28016\3821632356.py:4: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferWindowMemory(memory_key="chat_history",

# %% [markdown]
# ## Summary Buffer Memory

# %%
from langchain.memory import ConversationSummaryBufferMemory    

memory = ConversationSummaryBufferMemory(llm=llm, 
                                        return_messages=True, 
                                        max_token_limit=50) 
memory.clear()
memory.save_context({'human':'안녕하세요 챗봇님'},
                    {'bot':'안녕하세요! 반가워요, 호칭을 어떻게 하는게 좋을까요?'}) #context의 시작은 항상 사용자
memory.save_context({'human':'나는 홍길동입니다'},
                    {'bot':'네, 홍길동님 만나서 반갑습니다'})
memory.save_context({'human':'경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요'},
                    {'bot':'물론이죠. 경복궁은 지하철을 타고 가면 편리합니다'})
memory.save_context({'human':'몇 호선을 타고 가야하는지 아니?'},
                    {'bot':'3호선을 타고 가세요'})  

result= memory.load_memory_variables({})
print(result)  # 요약된 대화 내용 출력
# Out:
# C:\Users\JS\AppData\Local\Temp\ipykernel_28016\4221198333.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(llm=llm,
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[41], line 7
#       3 memory = ConversationSummaryBufferMemory(llm=llm,
#       4                                         return_messages=True,
#       5                                         max_token_limit=50)
#       6 memory.clear()
# ----> 7 memory.save_context({'human':'안녕하세요 챗봇님'},
#       8                     {'bot':'안녕하세요! 반가워요, 호칭을 어떻게 하는게 좋을까요?'}) #context의 시작은 항상 사용자
#       9 memory.save_context({'human':'나는 홍길동입니다'},
#      10                     {'bot':'네, 홍길동님 만나서 반갑습니다'})
#      11 memory.save_context({'human':'경복궁을 가고 싶은데 어떻게 가면 되는지 알려주세요'},
#      12                     {'bot':'물론이죠. 경복궁은 지하철을 타고 가면 편리합니다'})
#
# File c:\Users\JS\.conda\envs\ai\lib\site-packages\langchain\memory\summary_buffer.py:96, in ConversationSummaryBufferMemory.save_context(self, inputs, outputs)
#      94 """Save context from this conversation to buffer."""
#      95 super().save_context(inputs, outputs)
# ---> 96 self.prune()
#
# File c:\Users\JS\.conda\envs\ai\lib\site-packages\langchain\memory\summary_buffer.py:108, in ConversationSummaryBufferMemory.prune(self)
#     106 """Prune buffer if it exceeds max token limit"""
#     107 buffer = self.chat_memory.messages
# --> 108 curr_buffer_length = self.llm.get_num_tokens_from_messages(buffer)
#     109 if curr_buffer_length > self.max_token_limit:
#     110     pruned_memory = []
#
# File c:\Users\JS\.conda\envs\ai\lib\site-packages\langchain_openai\chat_models\base.py:1316, in BaseChatOpenAI.get_num_tokens_from_messages(self, messages, tools)
#    1314     tokens_per_name = 1
#    1315 else:
# -> 1316     raise NotImplementedError(
#    1317         f"get_num_tokens_from_messages() is not presently implemented "
#    1318         f"for model {model}. See "
#    1319         "https://platform.openai.com/docs/guides/text-generation/managing-tokens"  # noqa: E501
#    1320         " for information on how messages are converted to tokens."
#    1321     )
#    1322 num_tokens = 0
#    1323 messages_dict = [_convert_message_to_dict(m) for m in messages]
#
# NotImplementedError: get_num_tokens_from_messages() is not presently implemented for model cl100k_base. See https://platform.openai.com/docs/guides/text-generation/managing-tokens for information on how messages are converted to tokens.

# %%
from langchain.callbacks import get_openai_callback

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은 무엇인가요?")]
    response = llm.invoke(message)
    print(response.content)
    print(callback)
    print(callback.total_tokens)
# Out:
# 서울 광장시장은 다양한 길거리 음식으로 유명해서 "가장 맛있는 음식"을 한 가지로 꼽기 어렵지만, 방문객들과 현지인들에게 특히 인기 있는 대표 음식을 몇 가지 추천해드릴 수 있습니다.
#
# 1. **마약김밥**
#    - 광장시장의 시그니처 메뉴로, 한입 크기의 김밥에 특제 겨자 소스를 곁들여 먹는 것이 특징입니다. 중독성 있는 맛 덕분에 ‘마약김밥’이란 별명이 붙었습니다.
#
# 2. **빈대떡**
#    - 녹두를 갈아 만든 두툼한 빈대떡은 겉은 바삭하고 속은 촉촉해서 광장시장 대표 메뉴로 꼽힙니다. 막걸리와 곁들이면 최고의 궁합이에요.
#
# 3. **육회**
#    - 신선한 한우를 사용해 즉석에서 버무려 주는 육회도 인기 만점! 계란 노른자와 함께 비벼 먹으면 고소한 풍미가 일품입니다.
#
# 4. **족발/순대**
#    - 다른 시장에 비해 광장시장의 족발, 순대 역시 담백하고 잡내가 덜해 많은 사람들이 즐깁니다.
#
# 5. **떡볶이, 만두, 오뎅 등**
#    - 다양한 분식류와 함께 즉석에서 튀긴 만두, 어묵도 맛볼 수 있습니다. 각각의 점포마다 맛이 조금씩 달라 골라 먹는 재미가 있습니다.
#
# **가장 인기 많은 메뉴**는 단연 **마약김밥**과 **빈대떡**입니다. 많은 사람들이 이 두 가지를 먹으러 광장시장을 방문한다고 할 정도예요.
#
# **팁:**
# 광장시장은 먹거리 골목이 여러 개라서, 사람 많은 곳(줄이 길거나 북적이는 가게)을 찾으면 대부분 믿고 먹을 수 있습니다.
# 마약김밥, 빈대떡, 육회는 꼭 한번 드셔보시는 걸 추천합니다!
# Tokens Used: 480
# 	Prompt Tokens: 23
# 		Prompt Tokens Cached: 0
# 	Completion Tokens: 457
# 		Reasoning Tokens: 0
# Successful Requests: 1
# Total Cost (USD): $0.0037020000000000004
# 480

# %%
print (memory)
# Out:
# System: 당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다
# Human: 부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.
# AI: 부산에서 단 한 곳만 가야 한다면 저는 **해운대 해수욕장**을 추천드립니다.
#
# **이유:**
# - 부산을 대표하는 상징적인 바닷가입니다.
# - 넓고 깨끗한 백사장, 탁 트인 푸른 바다, 활기찬 분위기를 느낄 수 있습니다.
# - 해운대 주변에 고급 호텔, 카페, 레스토랑, 영화의전당 등 다양한 즐길 거리가 모여 있어 알찬 시간 보내기에 좋습니다.
# - 특히 동백섬, 해운대 블루라인파크(해변열차/스카이캡슐), 더베이 101 등과 가까워 산책과 사진 촬영, 맛집 탐방 등도 추가로 즐길 수 있습니다.
# - 계절을 막론하고 부산의 활기와 낭만, 해안 도시의 특별한 분위기를 가장 잘 느낄 수 있는 곳입니다.
#
# **아침, 낮, 일몰, 밤 모두 아름다운 매력을 지니고 있으니** 일정이 허락된다면 넉넉히 시간을 잡아 방문해 보세요!
